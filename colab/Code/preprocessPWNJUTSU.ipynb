# %%
from google.colab import drive
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
#
import os
drive.mount('/content/drive')


###

print(os.listdir('/content/drive/MyDrive/Data/system/'))

##
logs = pd.read_json('/content/drive/MyDrive/Data/pwnjutsu_n12.json',lines=True)#diavase os json object kathe line tou arxeiou

'''
with open('/content/drive/MyDrive/Data/pwnjutsu_n12.json','r') as file:
  lines = file.readlines()
  logs = [line.strip() for line in lines]
  logs = [json.loads(line) for line in lines]#h loads parsarei to json string kai to metatrepei se dict
logs = pd.DataFrame.from_dict(logs)
print(logs.iloc[0])
'''
def clean(raw):
  split = raw.split('type')
  if len(split) > 1:
    return 'type'+split[1]
  return raw
##
logs['raw'] = logs['raw'].apply(clean) # remove the node that is already present in the host column
print(logs.iloc[0])
##Analysis##
print('Host distinct values: ',logs['host'].value_counts())
print('Sourcetype distinct values: ',logs['sourcetype'].value_counts())
print('Source distinct values: ',logs['source'].value_counts())
#########
logs_linux_audit = logs[logs['sourcetype'] == 'linux_audit']
#####################
#
logs = []
dir = '/content/drive/MyDrive/Data/system/'
for file in tqdm(os.listdir(dir)):
  if file == 'pwnjutsu_dataset-system-json-n26.json':
    continue
  temp = pd.read_json(dir+file,lines=True)
  temp['raw'] = temp['raw'].apply(clean) #clean
  logs.append(temp)

###
logs = pd.concat(logs)#axis=0 default gia concat twn grammwn
logs.to_csv('/content/drive/MyDrive/Data/pwnjutsu.csv')
print('Description of logs: ',logs.describe())
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-4b6e1faf0512> in <cell line: 8>()
#       6 #
#       7 import os
# ----> 8 drive.mount('/content/drive')
#       9
#      10
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# --> 137     _message.blocking_request(
#     138         'request_auth',
#     139         request={'authType': 'dfs_ephemeral'},
#
# ...
