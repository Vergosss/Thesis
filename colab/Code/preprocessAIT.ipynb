# %%
from google.colab import drive
import pandas as pd
import numpy as np

drive.mount('/content/drive')
#

with open('/content/drive/MyDrive/Data/auth.log', 'r') as file:
  lines = file.readlines()
  lines = [line.strip() for line in lines]
#
df = pd.DataFrame(lines,columns=['Text'])
#1224->count
print(df.iloc[1223])
columns = ['Label','SubLabel']
labels = pd.read_csv('/content/drive/MyDrive/Data/auth_labels.csv',names=columns,header=None)
print('Label distinct values:',labels['Label'].value_counts())
print('SubLabel distinct values:',labels['SubLabel'].value_counts())
###
logs = pd.concat([df,labels],axis=1)
print('Columns are: ',logs.columns)
print(logs.iloc[734])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Text    Mar  6 04:39:01 mail CRON[10003]: pam_unix(cro...
# Name: 1223, dtype: object
# Label distinct values: Label
# 0                       936
# hydra                   286
# webshell-netstat-nau      2
# Name: count, dtype: int64
# SubLabel distinct values: SubLabel
# 0        938
# hydra    286
# Name: count, dtype: int64
# Columns are:  Index(['Text', 'Label', 'SubLabel'], dtype='object')
# Text        Mar  4 19:25:47 mail auth: pam_unix(dovecot:au...
# Label                                                   hydra
# SubLabel                                                hydra
# Name: 734, dtype: object
