# %%
from google.colab import drive
import pandas as pd
import numpy as np
import json
from tqdm import tqdm
#
import os
##
#!git clone https://github.com/wagga40/Zircolite.git
drive.mount('/content/drive')
'''
with open('/content/drive/MyDrive/Data/rules_linux.json') as file:
  rules_linux = json.load(file)
'''
##
#input('WAIT')

'''
Reading all logs then filtering them by sourcetype, getting all the linux audit ones
system_logs = pd.read_csv('/content/drive/MyDrive/Data/pwnjutsu.csv',index_col=0)
#
system_logs_audit = system_logs[system_logs['sourcetype'] == 'linux_audit']
print(system_logs_audit.sample(1))
##
system_logs_audit.to_csv('/content/drive/MyDrive/Data/system_logs_audit.csv',index=False)
#me to index=False den dimiourgeitai to unamed=0
'''
#Reading and printing the linux audit logs
system_logs_audit = pd.read_csv('/content/drive/MyDrive/Data/system_logs_audit.csv')
#
system_logs_audit.info()
print(system_logs_audit.describe())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5327621 entries, 0 to 5327620
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   raw         object
#  1   sourcetype  object
#  2   source      object
#  3   time        object
#  4   host        object
# dtypes: object(5)
# memory usage: 203.2+ MB
#                                                       raw   sourcetype  \
# count                                             5327621      5327621
# unique                                            5327293            1
# top     type=BPRM_FCAPS msg=audit(1620864001.189:12836...  linux_audit
# freq                                                    2      5327621
#
#                           source                         time     host
# count                    5327621                      5327621  5327621
# ...
